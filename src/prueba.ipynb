# %% [markdown]
# Este solo es un bloque de codigo para probar el desempenio del modelo

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

model = load_model(r'C:\Users\wipip\OneDrive\Documentos\GitHub\Clasificador-de-imagenes--main\models\best_model_vgg16.keras')

img_path = r'C:\Users\wipip\OneDrive\Documentos\GitHub\Clasificador-de-imagenes--main\6393714e2ee61.r_d.960-640-6250.jpeg'

img = image.load_img(img_path, target_size=(200, 200))
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)

if prediction[0][0] > prediction[0][1]:
    print("Predicción: Gato")
else:
    print("Predicción: Perro")

plt.imshow(img)
plt.title('Imagen de prueba')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Predicción: Gato
